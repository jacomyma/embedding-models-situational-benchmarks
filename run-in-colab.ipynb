# %% [markdown]
# <a href="https://colab.research.google.com/github/jacomyma/embedding-models-situational-benchmarks/blob/main/run-in-colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Run situational embedding benchmarks from Google Colab

# %% [markdown]
# ## Clone benchmark repository locally
# This use is typically thought for a use in a Google Colab environment.

# %%
# Clone GitHub repository
import os

repo_url = "https://github.com/jacomyma/embedding-models-situational-benchmarks"
repo_name = repo_url.split('/')[-1]

if not os.path.exists(repo_name):
    # !git clone {repo_url}
else:
    print(f"Repository '{repo_name}' already exists. Skipping clone.")

# %%
# Move "benchmark" folder to the root
# !mv {repo_name}/benchmark .

# Move "data" folder to the root
# !mv {repo_name}/data .

# %% [markdown]
# ## Install dependencies

# %%
# Run once
# !pip install sentence-transformers datasets scipy scikit-learn pandas tqdm

# %% [markdown]
# ## Setup & logging

# %%
import logging
import sys

logging.basicConfig(
    level=logging.INFO,
    format="%(asctime)s  %(levelname)-8s  %(message)s",
    datefmt="%H:%M:%S",
    stream=sys.stdout,
)

# Make sure the benchmark package is on the path
# (if running from the repo root this is not needed)
import os, sys
sys.path.insert(0, os.path.abspath(".."))

# %% [markdown]
# ## Inspect available tasks

# %%
from benchmark import TASK_REGISTRY

for name, task in TASK_REGISTRY.items():
    print(f"  {name:20s}  →  {task.description}")

# %%
# Which tasks to run
TASK_NAMES = ["likert-wvs"]

# %% [markdown]
# ## Define models to benchmark
#
# Models are plain dicts — no code changes needed to add/remove models.

# %%
MODEL_CONFIGS = [

    {
        "type": "sentence_transformer",
        "model": "sentence-transformers/multi-qa-MiniLM-L6-cos-v1",
        # MMTEB rank 192 on Feb 2026, low memory usage
    },
    {
        "type": "sentence_transformer",
        "model": "myrkur/sentence-transformer-parsbert-fa",
        # MMTEB rank 274 on Feb 2026, low memory usage
    },
    {
        "type": "sentence_transformer",
        "model": "BAAI/bge-base-en",
        # MMTEB rank 304 on Feb 2026, low memory usage
    },
    {
        "type": "sentence_transformer",
        "model": "intfloat/multilingual-e5-small",
        # MMTEB rank 29 on Feb 2026, low memory usage
    },
    {
        "type": "sentence_transformer",
        "model": "sentence-transformers/msmarco-distilbert-base-tas-b",
        # optimized for the task of semantic search
    },
    {
        "type": "sentence_transformer",
        "model": "sentence-transformers/static-similarity-mrl-multilingual-v1",
        # Recent, finetuned on various datasets, fast
    },
    {
        "type": "sentence_transformer",
        "model": "sentence-transformers/embeddinggemma-300m-medical",
        # Recent, trained on scientific medical papers using detailed medical questions
    },
    {
        "type": "sentence_transformer",
        "model": "sentence-transformers/allenai-specter",
        # For scientific paper abstracts and titles, quite light
    },
    {
        "type": "sentence_transformer",
        "model": "sentence-transformers/multi-qa-mpnet-base-dot-v1",
        # 5th most downloaded on HF
    },
    {
        "type": "sentence_transformer",
        "model": "sentence-transformers/paraphrase-multilingual-mpnet-base-v2",
        # MMTEB rank 38 on Feb 2026 - 4th most downloaded on HF
    },
    {
        "type": "sentence_transformer",
        "model": "sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2",
        # MMTEB rank 53 on Feb 2026 - 3rd most downloaded on HF
    },
    {
        "type": "sentence_transformer",
        "model": "sentence-transformers/all-mpnet-base-v2",
        # MMTEB rank 158 on Feb 2026 - 2nd most downloaded on HF
    },
    {
        "type": "sentence_transformer",
        "model": "BAAI/bge-m3",
        # MMTEB rank 23 on Feb 2026 - Pretty lightweight
    },
    {
        "type": "sentence_transformer",
        "model": "intfloat/e5-mistral-7b-instruct",
        # MMTEB rank 18 on Feb 2026
    },
    {
        "type": "sentence_transformer",
        "model": "GritLM/GritLM-7B",
        # MMTEB rank 15 on Feb 2026
    },
    {
        "type": "sentence_transformer",
        "model": "ICT-TIME-and-Querit/BOOM_4B_v1",
        # MMTEB rank 13 on Feb 2026
    },
    {
        "type": "sentence_transformer",
        "model": "intfloat/multilingual-e5-large-instruct",
        # MMTEB rank 12 on Feb 2026
    },
    {
        "type": "sentence_transformer",
        "model": "Alibaba-NLP/gte-Qwen2-7B-instruct",
        # MMTEB rank 10 on Feb 2026
    },
    {
        "type": "sentence_transformer",
        "model": "Qwen/Qwen3-Embedding-0.6B",
        # MMTEB rank 9 on Feb 2026
    },
    {
        "type": "sentence_transformer",
        "model": "bflhc/Octen-Embedding-8B",
        # MMTEB rank 7 on Feb 2026
    },
    {
        "type": "sentence_transformer",
        "model": "Qwen/Qwen3-Embedding-4B",
        "trust_remote_code": True,
        # MMTEB rank 5 on Feb 2026
    },
    {
        "type": "sentence_transformer",
        "model": "Qwen/Qwen3-Embedding-8B",
        "trust_remote_code": True,
        # MMTEB rank 3 on Feb 2026
    },
    {
        "type": "sentence_transformer",
        "model": "nvidia/llama-embed-nemotron-8b",
        "trust_remote_code": True,
        # MMTEB rank 2 on Feb 2026
    },
    {
        "type": "sentence_transformer",
        "model": "tencent/KaLM-Embedding-Gemma3-12B-2511",
        # MMTEB rank 1 on Feb 2026
    },
    {
        "type": "sentence_transformer",
        "model": "sentence-transformers/all-MiniLM-L6-v2",
        # Classic, slightly outdated; the most downloaded on HF
    },

    # Uncomment to add OpenAI (requires OPENAI_API_KEY):
    # {
    #     "type": "openai",
    #     "model": "text-embedding-3-small",
    # },
]

# %% [markdown]
# ## Run the benchmark

# %%
from pathlib import Path
from benchmark import BenchmarkRunner

runner = BenchmarkRunner(
    model_configs=MODEL_CONFIGS,
    task_names=TASK_NAMES,
    output_dir=Path("results"),
    cache_dir=Path(".cache/embeddings"),
    batch_size=128,
    show_progress=True,
)

results = runner.run()

# %% [markdown]
# ## Download results

# %%
import zipfile
import os
from google.colab import files

output_dir = "results"
zip_file_name = f"{output_dir}.zip"

# Create a zip file of the results directory
with zipfile.ZipFile(zip_file_name, 'w', zipfile.ZIP_DEFLATED) as zipf:
    for root, _, files_in_dir in os.walk(output_dir):
        for file in files_in_dir:
            zipf.write(os.path.join(root, file), os.path.relpath(os.path.join(root, file), output_dir))

print(f"Created '{zip_file_name}'.")

# Download the zip file
files.download(zip_file_name)
